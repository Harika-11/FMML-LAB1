# %% [markdown]
# <a href="https://colab.research.google.com/github/Harika-11/FMML-LABS-AND-ASSIGNMENTS/blob/main/Module_8_Lab__3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df

# %%
df['keywords']

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>LSH</span> <span style=''>Microbatches</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3753148614609572);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Gradients</span> <span style=''>Value</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Rearrangement</span> <br/><br/><span style=''>Metric</span> <span style='background-color:rgba(0, 255, 0, 0.32758620689655166);'>embeddings</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>immensely</span> <span style=''>useful</span> <span style='background-color:rgba(0, 255, 0, 0.3828125);'>representation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interacting</span> <span style=''>entities</span> <span style=''>such</span> <span style=''>as</span> <span style=''>videos</span> <span style=''>users</span> <span style=''>search</span> <span style=''>queries</span> <span style=''>online</span> <span style='background-color:rgba(0, 255, 0, 0.5384615384615383);'>resources</span> <span style=''>words</span> <span style=''>and</span> <span style=''>more</span> <span style='background-color:rgba(0, 255, 0, 0.32758620689655166);'>Embeddings</span> <span style=''>are</span> <span style=''>computed</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>a</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style=''>sum</span> <span style=''>over</span> <span style=''>provided</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associations</span> <span style=''>so</span> <span style=''>that</span> <span style=''>relation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>vectors</span> <span style=''>reflects</span> <span style=''>strength</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>association</span> <span style=''>Moreover</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style='background-color:rgba(0, 255, 0, 0.32758620689655166);'>embeddings</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style=''>predict</span> <span style=''>the</span> <span style=''>strength</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.5454545454545454);'>unobserved</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Typically</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>performs</span> <span style='background-color:rgba(255, 0, 0, 0.3753148614609572);'>stochastic</span> <span style=''>gradient</span> <span style=''>updates</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>minibatches</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associations</span> <span style=''>that</span> <span style=''>are</span> <span style=''>arranged</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independently</span> <span style=''>at</span> <span style=''>random</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>study</span> <span style=''>here</span> <span style=''>the</span> <span style=''>antithesis</span> <span style=''>of</span> <span style=''>em</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinated</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>arrangements</span> <span style=''>which</span> <span style=''>we</span> <span style=''>obtain</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Gaussian</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>scoring</span> <span style=''>of</span> <span style=''>a</span> <span style=''>heavy</span> <span style=''>tailed</span> <span style=''>PLDA</span> <span style=''>model</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Embeddings</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>are</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>complex</span> <span style=''>input</span> <span style=''>patterns</span> <span style=''>with</span> <span style=''>the</span> <span style=''>property</span> <span style=''>that</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geometric</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operations</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Euclidean</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>and</span> <span style=''>dot</span> <span style=''>products</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>are</span> <span style=''>special</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>that</span> <span style=''>live</span> <span style=''>in</span> <span style=''>more</span> <span style=''>general</span> <span style=''>inner</span> <span style=''>product</span> <span style=''>spaces</span> <span style=''>They</span> <span style=''>are</span> <span style=''>designed</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>propagate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>uncertainty</span> <span style=''>to</span> <span style=''>the</span> <span style=''>final</span> <span style=''>output</span> <span style=''>in</span> <span style=''>speaker</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recognition</span> <span style=''>and</span> <span style=''>similar</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>The</span> <span style=''>familiar</span> <span style=''>Gaussian</span> <span style=''>PLDA</span> <span style=''>model</span> <span style=''>(GPLDA)</span> <span style=''>can</span> <span style=''>be</span> <span style=''>re</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulated</span> <span style=''>as</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extractor</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>(GMEs)</span> <span style=''>such</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>ratio</span> <span style=''>scores</span> <span style=''>are</span> <span style=''>given</span> <span style=''>by</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style=''>inner</span> <span style=''>products</span> <span style=''>between</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='b ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>Exact</span> <span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Completion</span> <span style=''>with</span> <span style=''>Finite</span> <span style=''>Samples</span> <br/><br/><span style=''>Matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>is</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recovering</span> <span style=''>a</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observing</span> <span style=''>a</span> <span style=''>small</span> <span style=''>fraction</span> <span style=''>of</span> <span style=''>its</span> <span style=''>entries</span> <span style=''>A</span> <span style=''>series</span> <span style=''>of</span> <span style=''>recent</span> <span style=''>works</span> <span style=''>KOM12JNS13HW14</span> <span style=''>have</span> <span style=''>proposed</span> <span style=''>fast</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>However</span> <span style=''>the</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>in</span> <span style=''>all</span> <span style=''>these</span> <span style=''>results</span> <span style=''>is</span> <span style=''>sub</span> <span style=''>optimal</span> <span style=''>in</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.34246575342465746);'>dependence</span> <span style=''>on</span> <span style=''>the</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>number</span> <span style=''>and</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>accuracy</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>solves</span> <span style=''>the</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>completion</span> <span style=''>problem</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observing</span> <span style=''>O(nr5</span> <span style=''>log3</span> <span style=''>n)</span> <span style=''>entries</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>number</span> <span style=''>and</span> <span style=''>the</span> <span style=''>desired</span> <span style=''>accuracy</span> <span style=''>The</span> <span style=''>run</span> <span style=''>time</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>O(nr7log3</span> <span style=''>nlog</span> <span style=''>1epsilon)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>near</span> <span style=''>linear</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.30044843049327 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressive</span> <span style=''>Sampling</span> <span style=''>Using</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Algorithm</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Conventional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>of</span> <span style=''>sampling</span> <span style=''>signals</span> <span style=''>follow</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>celebrated</span> <span style=''>theorem</span> <span style=''>of</span> <span style=''>Nyquist</span> <span style=''>and</span> <span style=''>Shannon</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compressive</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>by</span> <span style=''>Donoho</span> <span style=''>Romberg</span> <span style=''>and</span> <span style=''>Tao</span> <span style=''>is</span> <span style=''>a</span> <span style=''>new</span> <span style=''>paradigm</span> <span style=''>that</span> <span style=''>goes</span> <span style=''>against</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>acquisition</span> <span style=''>and</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recovering</span> <span style=''>signals</span> <span style=''>using</span> <span style=''>fewer</span> <span style=''>samples</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>methods</span> <span style=''>use</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>suggest</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reconstructing</span> <span style=''>the</span> <span style=''>original</span> <span style=''>signals</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressive</span> <span style=''>sampling</span> <span style=''>using</span> <span style=''>EM</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>We</span> <span style=''>first</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>naive</span> <span style=''>approach</span> <span style=''>which</span> <span style=''>has</span> <span style=''>certain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulties</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsequently</span> <span style=''>modify</span> <span style=''>it</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style=''>approach</span> <span style=''>which</span> <span style=''>performs</span> <span style=''>better</span> <span style=''>than</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conventional</span> <span style=''>methods</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressive</span> <span style=''>sampling</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>and</span> <span style=''>the</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.09770937723693629)
# 	representation (0.12670007158196134)
# 	information (0.24266284896206156)
# 	architecture (0.08661417322834646)
# 	experimental (0.1385110952040086)
# 	segmentation (0.0737294201861131)
# 	detection (0.12168933428775948)
# 	different (0.2712956335003579)
# 	convolutional (0.12992125984251968)
# 	recognition (0.14280601288475303)
#
# Some Statistics words are:
# 	algorithm (0.386839481555334)
# 	theoretical (0.14755732801595214)
# 	stochastic (0.13609172482552342)
# 	statistical (0.1560319042871386)
# 	variables (0.1415752741774676)
# 	distribution (0.18045862412761715)
# 	estimation (0.17497507477567298)
# 	dimensional (0.18195413758723827)
# 	inference (0.19292123629112662)
# 	regression (0.17746759720837488)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e819ece4-b53e-4af9-85da-438f04c7e11d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e819ece4-b53e-4af9-85da-438f04c7e11d")) {                    Plotly.newPlot(                        "e819ece4-b53e-4af9-85da-438f04c7e11d",                        [{"x":["appropriate","metaheuristics","investigation","advantages","encodings","contributes","understanding","alternatives","drawbacks","challenging","representations","effective","neighborhood","experimental","reflected","structures","inventory","objective","searching","biobjective","regularized","associated","iterative","decomposed","intermediate","structure","techniques","deblurring","colorization","progressively","leveraged","annealing","algorithm","efficiency","resolution","splitting","approaches","experiments","inversion","denoising","extensive","demonstrate","algorithms","synthetic","processing","performance","introduce","behaviour","environment","assumptions","decentralized","congestion","abstraction","benchmark","resources","knowledge","satisfied","highlight","analysing","limitation","candidate","allocation","represent","considered","reinforcement","challenge","omnipresent","literature","difference","independent","applicability","promising","important","application","gradually","optimization","prediction","respectively","classification","increasing","characteristics","characteristic","principle","transmission","excellent","effectively","incoherent","information","different","performed","combining","previously","bioinformatics","improvement","available","efficient","expression","classifying","classifiers","unlabeled","independently","carcinoma","motivation","integrate","developed","evaluated","separation","outperforms","supervised","simultaneously","explained","conditions","prohibitively","technique","exploring","extensively","heuristic","reduction","typically","applicable","connection","scalability","heuristics","alternative","expensive","developing","establish","improving","functions","fundamental","nevertheless","direction","systematically","explicitly","engineering","protection","vulnerable","recognition","proprietary","adversarial","architecture","implications","procedure","attributes","vulnerability","automatic","optimisation","disclosed","continuous","parameter","providing","predictive","variables","modelling","movielens","incomplete","inference","recommender","corresponding","conditional","approximation","dependence","predicted","posterior","parametric","distribution","bivariate","approximate","advantage","transform","diagnosis","represented","probability","illustrated","assignment","uncertainty","reasonable","methodology","combination","presented","concatenation","mechanism","modalities","improvements","effectiveness","multimodal","outputting","attention","answering","translation","investigated","recurrent","instances","tremendous","innovations","assessing","treatment","detection","encouraging","artificial","numerical","derivative","regularization","segmentation","addresses","formulation","variational","unsupervised","introduced","dimensional","particularly","variations","illumination","descriptor","clustering","explosive","applications","complementary","clustered","considerable","extracted","difficulties","environmental","surveillance","resistant","additional","scenarios","occlusion","considers","furthermore","exploration","exploitation","achieving","encourages","obviously","essentially","validation","obtaining","successful","surprising","consuming","determining","incorporate","performing","selecting","interactions","shortened","extensions","intensively","imperceptibility","motivates","computation","propagation","perturbations","perturbed","temporally","mis ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	challenged
# 	emphdirectly
# 	boundedness
# 	procrustes
# 	summation
# 	bhattacharyya
# 	polarimetric
# 	epigenomics
# 	increments
# 	epidemiology
# 	automates
# 	inclusions
# 	penalization
# 	detectability
# 	ultrametric
# 	penalised
# 	encrypted
# 	nonconjugate
# 	terabytes
# 	pseudolikelihood
# Some words which never appear in Statistics papers:
# 	metaheuristics
# 	biobjective
# 	deblurring
# 	colorization
# 	congestion
# 	carcinoma
# 	concatenation
# 	outputting
# 	illumination
# 	shortened
# 	imperceptibility
# 	persuasion
# 	personalities
# 	installed
# 	multiplicity
# 	suppression
# 	confidences
# 	hypernyms
# 	associating
# 	occlusions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0741799624950045e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7483333333333333
